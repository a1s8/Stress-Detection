# %% [markdown]
# ## Model fitting and evaluation

# %%
Y_train = df_combined["stress_level"]
X_train = df_combined.drop(["stress_level"], axis= 1)
Y_test = test["stress_level"]
X_test = test.drop(["stress_level"], axis= 1)

# %%
Y_train=Y_train.astype(int)

# %%
print("X_train shape is",X_train.shape)
print("X_test shape is",X_test.shape)
print("Y_train shape is",Y_train.shape)
print("Y_test shape is",Y_test.shape)
# Out:
# X_train shape is (944, 8)
# X_test shape is (158, 8)
# Y_train shape is (944,)
# Y_test shape is (158,)

# %% [markdown]
# ### 1.) K-Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# Define parameter grid
param_grid = {
    "n_neighbors": range(1, 31),
    "weights": ["uniform", "distance"],  
    "metric": ["euclidean", "manhattan", "minkowski"]
}

# Initialize KNN model
knn = KNeighborsClassifier()

# Perform GridSearchCV
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring="accuracy", n_jobs=-1, verbose=2)
grid_search.fit(X_train, Y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# Best Parameters: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}

# %%
knn = KNeighborsClassifier(metric="manhattan", n_neighbors=5, weights="uniform")
knn_model = knn.fit(X_train, Y_train)
knn_model
# Out:
# KNeighborsClassifier(metric='manhattan')

# %%
Y_pred_train = knn_model.predict(X_train)
Y_pred_test = knn_model.predict(X_test)
print("Train Accuracy:",accuracy_score(Y_train, Y_pred_train),"\n""Test Accuracy:",accuracy_score(Y_test, Y_pred_test))
# Out:
# Train Accuracy: 0.9936440677966102
# Test Accuracy: 1.0

# %%
print(classification_report(Y_test, Y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        32
#            1       1.00      1.00      1.00        34
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        36
#            4       1.00      1.00      1.00        27
#
#     accuracy                           1.00       158
#    macro avg       1.00      1.00      1.00       158
# weighted avg       1.00      1.00      1.00       158

# %% [markdown]
# ### 2.) Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter grid 
param_dist = {
    "n_estimators": np.arange(100, 1000, 50), 
    "max_depth": np.arange(5, 50, 2),  
    "min_samples_split": np.arange(1, 20),  
    "min_samples_leaf": np.arange(1, 10),  
    "max_features": ["sqrt", "log2", None],  
    "bootstrap": [True, False]  
}

# Create Random Forest model
rf = RandomForestClassifier(random_state=42)

# RandomizedSearchCV 
random_search = RandomizedSearchCV(estimator=rf, param_distributions=param_dist, n_iter=20, cv=5, scoring='accuracy', 
                                      n_jobs=-1, verbose=2, random_state=42)

# Fit the model
random_search.fit(X_train, Y_train)

# Best parameters
print("Best Parameters:", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'n_estimators': 750, 'min_samples_split': 7, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 19, 'bootstrap': False}

# %%
rf_model = RandomForestClassifier(
    n_estimators=750,    
    criterion='gini',
    max_features="sqrt",
    min_samples_split=7,
    min_samples_leaf=4,
    max_depth=19, 
    random_state=42)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=19, min_samples_leaf=4, min_samples_split=7,
#                        n_estimators=750, random_state=42)

# %%
Y_pred_train = rf_model.predict(X_train)
Y_pred_test = rf_model.predict(X_test)
print("Train Accuracy:",accuracy_score(Y_train, Y_pred_train),"\n""Test Accuracy",accuracy_score(Y_test, Y_pred_test))
# Out:
# Train Accuracy: 0.9947033898305084
# Test Accuracy 0.9936708860759493

# %%
print(classification_report(Y_test, Y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        32
#            1       1.00      0.97      0.99        34
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        36
#            4       1.00      1.00      1.00        27
#
#     accuracy                           0.99       158
#    macro avg       0.99      0.99      0.99       158
# weighted avg       0.99      0.99      0.99       158

# %% [markdown]
# ### 3.) Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression()
logistic_model.fit(X_train,Y_train)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction_train = np.round(logistic_model.predict(X_train))
prediction_test = np.round(logistic_model.predict(X_test))
print("Train Accuracy:",accuracy_score(Y_train,prediction_train),"\n""Test Accuracy:",accuracy_score(Y_test,prediction_test))
# Out:
# Train Accuracy: 0.9788135593220338
# Test Accuracy: 0.9556962025316456

# %%
print(classification_report(Y_test, prediction_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93        32
#            1       0.89      1.00      0.94        34
#            2       0.94      1.00      0.97        29
#            3       0.97      0.94      0.96        36
#            4       1.00      0.96      0.98        27
#
#     accuracy                           0.96       158
#    macro avg       0.96      0.96      0.96       158
# weighted avg       0.96      0.96      0.96       158

# %% [markdown]
# ### 4.) Support Vector Classifier

# %%
from sklearn.svm import SVC

# Define the parameter grid
param_grid = {
    "C": [0.1, 1, 10],  
    "kernel": ["linear", "rbf"],  
    "gamma": ["scale", "auto", 0.01, 0.1]
}

# Initialize SVC
svc = SVC()

# Perform Grid Search
grid_search = GridSearchCV(svc, param_grid, cv=5, scoring="accuracy", n_jobs=-1, verbose=1)

# Fit model
grid_search.fit(X_train, Y_train)

# Best Parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best Parameters: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
svc_model = SVC(kernel='rbf', C=1, gamma=0.01)
svc_model.fit(X_train, Y_train)
# Out:
# SVC(C=1, gamma=0.01)

# %%
Y_pred_train = svc_model.predict(X_train)
Y_pred_test = svc_model.predict(X_test)
print("Train Accuracy:",accuracy_score(Y_train, Y_pred_train),"\n""Test Accuracy:",accuracy_score(Y_test, Y_pred_test))
# Out:
# Train Accuracy: 0.9936440677966102
# Test Accuracy: 0.9746835443037974

# %%
print(classification_report(Y_test, Y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        32
#            1       1.00      1.00      1.00        34
#            2       0.97      0.97      0.97        29
#            3       0.92      0.97      0.95        36
#            4       1.00      1.00      1.00        27
#
#     accuracy                           0.97       158
#    macro avg       0.98      0.98      0.98       158
# weighted avg       0.98      0.97      0.97       158

# %% [markdown]
# ### 5.) Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
nb_model.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
Y_pred_train = nb_model.predict(X_train)
Y_pred_test = nb_model.predict(X_test)
print("Train Accuracy:",accuracy_score(Y_train, Y_pred_train),"\n""Test Accuracy:",accuracy_score(Y_test, Y_pred_test))
# Out:
# Train Accuracy: 0.9788135593220338
# Test Accuracy: 0.9620253164556962

# %%
print(classification_report(Y_test, Y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95        32
#            1       0.94      0.97      0.96        34
#            2       0.94      1.00      0.97        29
#            3       0.97      0.94      0.96        36
#            4       1.00      0.96      0.98        27
#
#     accuracy                           0.96       158
#    macro avg       0.96      0.96      0.96       158
# weighted avg       0.96      0.96      0.96       158

# %% [markdown]
# ### 6.) CatBoost Classifier

# %%
from catboost import CatBoostClassifier

# Define parameter grid
param_grid = {
    "iterations": [200, 500], 
    "learning_rate": [0.03, 0.1],  
    "depth": [4, 6, 8],  
    "l2_leaf_reg": [1, 3, 5],  
}

# Initialize CatBoostClassifier
catboost = CatBoostClassifier(verbose=0)

# Perform Grid Search
grid_search = GridSearchCV(catboost, param_grid, cv=5, scoring="accuracy", n_jobs=-1, verbose=2)
grid_search.fit(X_train, Y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best Parameters: {'depth': 8, 'iterations': 200, 'l2_leaf_reg': 1, 'learning_rate': 0.03}

# %%
cb_model = CatBoostClassifier(random_state = 42, iterations=200, depth=8, learning_rate=0.03, l2_leaf_reg=1)
cb_model.fit(X_train, Y_train)
# Out:
# 0:	learn: 1.5118095	total: 237ms	remaining: 47.2s
# 1:	learn: 1.4251454	total: 286ms	remaining: 28.3s
# 2:	learn: 1.3472667	total: 326ms	remaining: 21.4s
# 3:	learn: 1.2780060	total: 365ms	remaining: 17.9s
# 4:	learn: 1.2113925	total: 414ms	remaining: 16.1s
# 5:	learn: 1.1517758	total: 490ms	remaining: 15.8s
# 6:	learn: 1.0968555	total: 538ms	remaining: 14.8s
# 7:	learn: 1.0459552	total: 578ms	remaining: 13.9s
# 8:	learn: 0.9975863	total: 623ms	remaining: 13.2s
# 9:	learn: 0.9552527	total: 668ms	remaining: 12.7s
# 10:	learn: 0.9169212	total: 716ms	remaining: 12.3s
# 11:	learn: 0.8797469	total: 761ms	remaining: 11.9s
# 12:	learn: 0.8445233	total: 806ms	remaining: 11.6s
# 13:	learn: 0.8111654	total: 849ms	remaining: 11.3s
# 14:	learn: 0.7814804	total: 926ms	remaining: 11.4s
# 15:	learn: 0.7524660	total: 1.03s	remaining: 11.8s
# 16:	learn: 0.7242023	total: 1.08s	remaining: 11.7s
# 17:	learn: 0.6980093	total: 1.14s	remaining: 11.5s
# 18:	learn: 0.6739389	total: 1.2s	remaining: 11.4s
# 19:	learn: 0.6491078	total: 1.26s	remaining: 11.3s
# 20:	learn: 0.6279950	total: 1.31s	remaining: 11.1s
# 21:	learn: 0.6058279	total: 1.35s	remaining: 10.9s
# 22:	learn: 0.5851977	total: 1.39s	remaining: 10.7s
# 23:	learn: 0.5654113	total: 1.43s	remaining: 10.5s
# 24:	learn: 0.5469684	total: 1.47s	remaining: 10.3s
# 25:	learn: 0.5293776	total: 1.52s	remaining: 10.2s
# 26:	learn: 0.5127595	total: 1.56s	remaining: 10s
# 27:	learn: 0.4975926	total: 1.57s	remaining: 9.64s
# 28:	learn: 0.4813560	total: 1.61s	remaining: 9.5s
# 29:	learn: 0.4666949	total: 1.65s	remaining: 9.35s
# 30:	learn: 0.4525369	total: 1.69s	remaining: 9.22s
# 31:	learn: 0.4383056	total: 1.75s	remaining: 9.17s
# 32:	learn: 0.4250996	total: 1.79s	remaining: 9.05s
# 33:	learn: 0.4122689	total: 1.83s	remaining: 8.92s
# 34:	learn: 0.4003384	total: 1.87s	remaining: 8.8s
# 35:	learn: 0.3883139	total: 1.91s	remaining: 8.72s
# 36:	learn: 0.3771309	total: 1.97s	remaining: 8.7s
# 37:	learn: 0.3662966	total: 2.02s	remaining: 8.6s
# 38:	learn: 0.3555808	total: 2.06s	remaining: 8.49s
# 39:	learn: 0.3459173	total: 2.1s	remaining: 8.39s
# 40:	learn: 0.3360659	total: 2.14s	remaining: 8.29s
# 41:	learn: 0.3264719	total: 2.2s	remaining: 8.26s
# 42:	learn: 0.3178201	total: 2.23s	remaining: 8.16s
# 43:	learn: 0.3092112	total: 2.27s	remaining: 8.06s
# 44:	learn: 0.3009443	total: 2.31s	remaining: 7.97s
# 45:	learn: 0.2929602	total: 2.35s	remaining: 7.88s
# 46:	learn: 0.2853800	total: 2.41s	remaining: 7.84s
# 47:	learn: 0.2775068	total: 2.45s	remaining: 7.76s
# 48:	learn: 0.2703478	total: 2.49s	remaining: 7.68s
# 49:	learn: 0.2633224	total: 2.53s	remaining: 7.59s
# 50:	learn: 0.2560658	total: 2.57s	remaining: 7.51s
# 51:	learn: 0.2495509	total: 2.65s	remaining: 7.55s
# 52:	learn: 0.2428523	total: 2.71s	remaining: 7.52s
# 53:	learn: 0.2368001	total: 2.75s	remaining: 7.44s
# 54:	learn: 0.2309810	total: 2.83s	remaining: 7.46s
# 55:	learn: 0.2250876	total: 2.88s	remaining: 7.39s
# 56:	learn: 0.2195654	total: 2.93s	remaining: 7.34s
# 57:	learn: 0.2140119	total: 3s	remaining: 7.34s
# 58:	learn: 0.2088699	total: 3.05s	remaining: 7.29s
# 59:	learn: 0.2040977	total: 3.12s	remaining: 7.28s
# 60:	learn: 0.1994217	total: 3.17s	remaining: 7.22s
# 61:	learn: 0.1947490	total: 3.22s	remaining: 7.16s
# 62:	learn: 0.1900626	total: 3.28s	remaining: 7.14s
# 63:	learn: 0.1854723	total: 3.33s	remaining: 7.08s
# 64:	learn: 0.1811095	total: 3.38s	remaining: 7.02s
# 65:	learn: 0.1768803	total: 3.43s	remaining: 6.96s
# 66:	learn: 0.1730707	total: 3.5s	remaining: 6.96s
# 67:	learn: 0.1692556	total: 3.61s	remaining: 7.01s
# 68:	learn: 0.1654280	total: 3.67s	remaining: 6.97s
# 69:	learn: 0.1618914	total: 3.73s	remaining: 6.92s
# 70:	learn: 0.1584897	total: 3.79s	remaining: 6.88s
# 71:	learn: 0.1551960	total: 3.84s	remaining: 6.82s
# 72:	learn: 0.1518125	total: 3.89s	remaining: 6.76s
# 73:	learn: 0.1484963	total: 3.94s	remaining: 6.7s
# 74:	learn: 0.1451878	total: 4s	remaining: 6.67s
# 75:	learn: 0.1420807	total: 4.04s	remaining: 6.59s
# 76:	learn: 0.1390349	total: 4.09s	remaining: 6.53s
# 77:	learn: 0.1360797	total: 4.13s	remaining: 6.46s
# 78:	learn: 0.1331579	total: 4.19s	remaining: 6.42s
# 79:	learn: 0.1303501	total: 4.27s	remaining: 6.4s
# 80:	learn: 0.1276979	total: 4.35s	remaining: 6.39s
# 81:	learn: 0.1250366	total: 4.43s	remaining: 6.38s
# 82:	learn: 0.1227254	total: 4.49s	remaining: 6.33s
# 83:	learn: 0.1201979	total: 4.54s	remaining: 6.27s
# 84:	learn: 0.1178910	total: 4.59s	remaining: 6.21s
# 85:	learn: 0.1155859	total: 4.64s	remaining: 6.15s
# 86:	learn: 0.1132358	total: 4.74s	remaining: 6.15s
# 87:	learn: 0.1110810	total: 4.79s	remaining: 6.1s
# 88:	learn: 0.1090454	total: 4.85s	remaining: 6.04s
# 89:	learn: 0.1069961	total: 4.91s	remaining: 6s
# 90:	learn: 0.1049592	total: 4.96s	remaining: 5.94s
# 91:	learn: 0.1031748	total: 5.02s	remaining: 5.89s
# 92:	learn: 0.1012256	total: 5.07s	remaining: 5.83s
# 93:	learn: 0.0993502	total: 5.12s	remaining: 5.77s
# 94:	learn: 0.0975661	total: 5.18s	remaining: 5.72s
# 95:	learn: 0.0959007	total: 5.22s	remaining: 5.66s
# 96:	learn: 0.0941311	total: 5.27s	remaining: 5.59s
# 97:	learn: 0.0924428	total: 5.31s	remaining: 5.53s
# 98:	learn: 0.0908611	total: 5.36s	remaining: 5.47s
# 99:	learn: 0.0894884	total: 5.41s	remaining: 5.41s
# 100:	learn: 0.0879743	total: 5.47s	remaining: 5.36s
# 101:	learn: 0.0864803	total: 5.51s	remaining: 5.3s
# 102:	learn: 0.0850227	total: 5.57s	remaining: 5.24s
# 103:	learn: 0.0837174	total: 5.63s	remaining: 5.2s
# 104:	learn: 0.0825021	total: 5.71s	remaining: 5.17s
# 105:	learn: 0.0813148	total: 5.77s	remaining: 5.11s
# 106:	learn: 0.0800905	total: 5.82s	remaining: 5.06s
# 107:	learn: 0.0787746	total: 5.95s	remaining: 5.07s
# 108:	learn: 0.0776743	total: 6.06s	remaining: 5.06s
# 109:	learn: 0.0763692	total: 6.13s	remaining: 5.01s
# 110:	learn: 0.0751768	total: 6.18s	remaining: 4.96s
# 111:	learn: 0.0740883	total: 6.26s	remaining: 4.92s
# 112:	learn: 0.0729722	total: 6.3s	remaining: 4.85s
# 113:	learn: 0.0720496	total: 6.35s	remaining: 4.79s
# 114:	learn: 0.0710346	total: 6.4s	remaining: 4.73s
# 115:	learn: 0.0701211	total: 6.45s	remaining: 4.67s
# 116:	learn: 0.0691237	total: 6.49s	remaining: 4.6s
# 117:	learn: 0.0680887	total: 6.53s	remaining: 4.54s
# 118:	learn: 0.0672008	total: 6.59s	remaining: 4.48s
# 119:	learn: 0.0662770	total: 6.67s	remaining: 4.45s
# 120:	learn: 0.0654195	total: 6.73s	remaining: 4.39s
# 121:	learn: 0.0646117	total: 6.78s	remaining: 4.33s
# 122:	learn: 0.0637884	total: 6.83s	remaining: 4.27s
# 123:	learn: 0.0630415	total: 6.87s	remaining: 4.21s
# 124:	learn: 0.0621352	total: 6.93s	remaining: 4.16s
# 125:	learn: 0.0614101	total: 6.98s	remaining: 4.1s
# 126:	learn: 0.0606851	total: 7.03s	remaining: 4.04s
# 127:	learn: 0.0599455	total: 7.08s	remaining: 3.98s
# 128:	learn: 0.0592410	total: 7.13s	remaining: 3.92s
# 129:	learn: 0.0585567	total: 7.29s	remaining: 3.92s
# 130:	learn: 0.0577062	total: 7.34s	remaining: 3.87s
# 131:	learn: 0.0570114	total: 7.38s	remaining: 3.8s
# 132:	learn: 0.0562996	total: 7.43s	remaining: 3.74s
# 133:	learn: 0.0556392	total: 7.47s	remaining: 3.68s
# 134:	learn: 0.0549211	total: 7.52s	remaining: 3.62s
# 135:	learn: 0.0542354	total: 7.58s	remaining: 3.56s
# 136:	learn: 0.0536446	total: 7.64s	remaining: 3.51s
# 137:	learn: 0.0528398	total: 7.7s	remaining: 3.46s
# 138:	learn: 0.0522674	total: 7.76s	remaining: 3.4s
# 139:	learn: 0.0516515	total: 7.82s	remaining: 3.35s
# 140:	learn: 0.0510581	total: 7.9s	remaining: 3.31s
# 141:	learn: 0.0504932	total: 7.99s	remaining: 3.27s
# 142:	learn: 0.0499551	total: 8.04s	remaining: 3.2s
# 143:	learn: 0.0493568	total: 8.09s	remaining: 3.14s
# 144:	learn: 0.0488851	total: 8.14s	remaining: 3.09s
# 145:	learn: 0.0483401	total: 8.18s	remaining: 3.03s
# 146:	learn: 0.0478052	total: 8.24s	remaining: 2.97s
# 147:	learn: 0.0472697	total: 8.29s	remaining: 2.91s
# 148:	learn: 0.0467642	total: 8.33s	remaining: 2.85s
# 149:	learn: 0.0462734	total: 8.38s	remaining: 2.79s
# 150:	learn: 0.0458122	total: 8.43s	remaining: 2.73s
# 151:	learn: 0.0453535	total: 8.48s	remaining: 2.68s
# 152:	learn: 0.0448868	total: 8.53s	remaining: 2.62s
# 153:	learn: 0.0444334	total: 8.57s	remaining: 2.56s
# 154:	learn: 0.0439874	total: 8.61s	remaining: 2.5s
# 155:	learn: 0.0435750	total: 8.65s	remaining: 2.44s
# 156:	learn: 0.0432676	total: 8.69s	remaining: 2.38s
# 157:	learn: 0.0428837	total: 8.73s	remaining: 2.32s
# 158:	learn: 0.0425123	total: 8.78s	remaining: 2.26s
# 159:	learn: 0.0421083	total: 8.82s	remaining: 2.2s
# 160:	learn: 0.0416876	total: 8.86s	remaining: 2.15s
# 161:	learn: 0.0413187	total: 8.9s	remaining: 2.09s
# 162:	learn: 0.0409634	total: 8.94s	remaining: 2.03s
# 163:	learn: 0.0405312	total: 8.99s	remaining: 1.97s
# 164:	learn: 0.0401120	total: 9.03s	remaining: 1.92s
# 165:	learn: 0.0397194	total: 9.07s	remaining: 1.86s
# 166:	learn: 0.0394014	total: 9.12s	remaining: 1.8s
# 167:	learn: 0.0390294	total: 9.16s	remaining: 1.75s
# 168:	learn: 0.0387034	total: 9.21s	remaining: 1.69s
# 169:	learn: 0.0384084	total: 9.24s	remaining: 1.63s
# 170:	learn: 0.0380411	total: 9.29s	remaining: 1.57s
# 171:	learn: 0.0376137	total: 9.33s	remaining: 1.52s
# 172:	learn: 0.0371649	total: 9.37s	remaining: 1.46s
# 173:	learn: 0.0368580	total: 9.41s	remaining: 1.41s
# 174:	learn: 0.0365497	total: 9.46s	remaining: 1.35s
# 175:	learn: 0.0362525	total: 9.49s	remaining: 1.29s
# 176:	learn: 0.0359500	total: 9.53s	remaining: 1.24s
# 177:	learn: 0.0356406	total: 9.59s	remaining: 1.18s
# 178:	learn: 0.0353163	total: 9.64s	remaining: 1.13s
# 179:	learn: 0.0350230	total: 9.68s	remaining: 1.08s
# 180:	learn: 0.0347903	total: 9.72s	remaining: 1.02s
# 181:	learn: 0.0344805	total: 9.76s	remaining: 966ms
# 182:	learn: 0.0341771	total: 9.8s	remaining: 911ms
# 183:	learn: 0.0338583	total: 9.85s	remaining: 857ms
# 184:	learn: 0.0336227	total: 9.89s	remaining: 802ms
# 185:	learn: 0.0333804	total: 9.93s	remaining: 747ms
# 186:	learn: 0.0331189	total: 9.97s	remaining: 693ms
# 187:	learn: 0.0328651	total: 10s	remaining: 639ms
# 188:	learn: 0.0326715	total: 10.1s	remaining: 585ms
# 189:	learn: 0.0323768	total: 10.1s	remaining: 531ms
# 190:	learn: 0.0321395	total: 10.1s	remaining: 478ms
# 191:	learn: 0.0318849	total: 10.2s	remaining: 424ms
# 192:	learn: 0.0315801	total: 10.2s	remaining: 371ms
# 193:	learn: 0.0312976	total: 10.3s	remaining: 318ms
# 194:	learn: 0.0310626	total: 10.3s	remaining: 264ms
# 195:	learn: 0.0307612	total: 10.4s	remaining: 211ms
# 196:	learn: 0.0305579	total: 10.4s	remaining: 158ms
# 197:	learn: 0.0303282	total: 10.4s	remaining: 105ms
# 198:	learn: 0.0301389	total: 10.5s	remaining: 52.7ms
# 199:	learn: 0.0298741	total: 10.5s	remaining: 0us

# %%
Y_pred_train = cb_model.predict(X_train)
Y_pred_test = cb_model.predict(X_test)
print("Train Accuracy:",accuracy_score(Y_train, Y_pred_train),"\n""Test Accuracy:",accuracy_score(Y_test, Y_pred_test))
# Out:
# Train Accuracy: 0.9947033898305084
# Test Accuracy: 0.9873417721518988

# %%
print(classification_report(Y_test, Y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        32
#            1       0.94      1.00      0.97        34
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        36
#            4       1.00      1.00      1.00        27
#
#     accuracy                           0.99       158
#    macro avg       0.99      0.99      0.99       158
# weighted avg       0.99      0.99      0.99       158

# %% [markdown]
# ## Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

models = {"KNN":knn_model,"RandomForest":rf_model,"Logistic":logistic_model,"SVC":svc_model,"NaiveBayes":nb_model,"CatBoost":cb_model}

# Perform cross-validation for each model
cv_results = {}

for name, model in models.items():
    scores = cross_val_score(model, X_train, Y_train, cv=5, scoring="accuracy", n_jobs=-1)
    cv_results[name] = (np.mean(scores), np.std(scores))
    print(f"{name}: Mean Accuracy = {np.mean(scores):.4f} ± {np.std(scores):.4f}")

# Display sorted results
sorted_results = sorted(cv_results.items(), key=lambda x: x[1][0], reverse=True)
print("\nCross-Validation Summary")
for name, (mean_acc, std_acc) in sorted_results:
    print(f"{name}: {mean_acc:.4f} ± {std_acc:.4f}")
# Out:
# KNN: Mean Accuracy = 0.9936 ± 0.0085
# RandomForest: Mean Accuracy = 0.9936 ± 0.0085
# Logistic: Mean Accuracy = 0.9650 ± 0.0110
# SVC: Mean Accuracy = 0.9883 ± 0.0091
# NaiveBayes: Mean Accuracy = 0.9608 ± 0.0179
# CatBoost: Mean Accuracy = 0.9947 ± 0.0067
#
# Cross-Validation Summary
# CatBoost: 0.9947 ± 0.0067
# KNN: 0.9936 ± 0.0085
# RandomForest: 0.9936 ± 0.0085
# SVC: 0.9883 ± 0.0091
# Logistic: 0.9650 ± 0.0110
# NaiveBayes: 0.9608 ± 0.0179
